# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_raw = cv2.imread("/home/ahmed/Desktop/wordpress/note20.jpeg")

# %%
img = cv2.cvtColor(img_raw, cv2.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray')

# %%
imagem = cv2.bitwise_not(img)
plt.imshow(imagem)

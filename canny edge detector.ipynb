# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import math
# %matplotlib inline

# %%
img = cv2.imread("/home/ahmed/Desktop/wordpress/cat1.jpeg",0)
img1 = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
canny = cv2.Canny(img1,150,250)

# %%
canny = cv2.cvtColor(canny,cv2.COLOR_GRAY2RGB)
plt.imshow(canny)
